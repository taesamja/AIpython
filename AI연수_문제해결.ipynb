# %% [markdown]
# <a href="https://colab.research.google.com/github/taesamja/AIpython/blob/master/AI%EC%97%B0%EC%88%98_%EB%AC%B8%EC%A0%9C%ED%95%B4%EA%B2%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 해결문제)
# 기상청에서 제공하는 지역별 식중독 지수를 참고하여 해당 지역의 단계를 설정하고 대응요령을 출력하시오.
# - 단계별 대응
#   - 위험 : 86 이상
#     - 설사, 구토 등 식중독 의심 증상이 있으면 의료기관을 방문하여 의사 지시에 따름
#   - 경고:71 이상 86 미만
#     - 조리도구는 세척, 소독 등을 거쳐 세균오염을 방지하고 유통기한, 보관방법 등을 확인하여 음식물 조리. 보관에 각별히 주의하여야 함
#   - 주의:55 이상 71 미만
#     - 조리음식은 중심부까지 75℃(어패류 85℃)로 1분 이상 완전히 익히고 외부로 운반할 때에는 가급적 아이스박스 등을 이용하여 10℃이하에서 보관 및 운반
#   - 관심:55 미만
#     - 화장실 사용 후, 귀가 후, 조리 전에 손 씻기를 생활화

# %%
show = {'위험':'설사, 구토 등 식중독 의심 증상이 있으면 의료기관을 방문하여 의사 지시에 따름', 
        '경고':'조리도구는 세척, 소독 등을 거쳐 세균오염을 방지하고 유통기한, 보관방법 등을 확인하여 음식물 조리. 보관에 각별히 주의하여야 함', 
        '주의':'조리음식은 중심부까지 75℃(어패류 85℃)로 1분 이상 완전히 익히고 외부로 운반할 때에는 가급적 아이스박스 등을 이용하여 10℃이하에서 보관 및 운반', 
        '관심':'화장실 사용 후, 귀가 후, 조리 전에 손 씻기를 생활화' }

area = {"서울시":99, "부산시":72, "대구시":59,
        "인천시":53, "강화군":98, "서해5도":74,
        "광주시":62, "대전시":50, "울산시":97, "세종시":78}

for loc in area:
  if area[loc] >= 86:  
    print(f'{loc}의 식중독 지수 => 위험 : {show["위험"]}')
  elif area[loc] >= 71:
    print(f'{loc}의 식중독 지수 => 경고 : {show["경고"]}')
  elif area[loc] >= 55:
    print(f'{loc}의 식중독 지수 => 주의 : {show["주의"]}')
  else :
    print(f'{loc}의 식중독 지수 => 관심 : {show["관심"]}')
# Out:
# 서울시의 식중독 지수 => 위험 : 설사, 구토 등 식중독 의심 증상이 있으면 의료기관을 방문하여 의사 지시에 따름
# 부산시의 식중독 지수 => 경고 : 조리도구는 세척, 소독 등을 거쳐 세균오염을 방지하고 유통기한, 보관방법 등을 확인하여 음식물 조리. 보관에 각별히 주의하여야 함
# 대구시의 식중독 지수 => 주의 : 조리음식은 중심부까지 75℃(어패류 85℃)로 1분 이상 완전히 익히고 외부로 운반할 때에는 가급적 아이스박스 등을 이용하여 10℃이하에서 보관 및 운반
# 인천시의 식중독 지수 => 관심 : 화장실 사용 후, 귀가 후, 조리 전에 손 씻기를 생활화
# 강화군의 식중독 지수 => 위험 : 설사, 구토 등 식중독 의심 증상이 있으면 의료기관을 방문하여 의사 지시에 따름
# 서해5도의 식중독 지수 => 경고 : 조리도구는 세척, 소독 등을 거쳐 세균오염을 방지하고 유통기한, 보관방법 등을 확인하여 음식물 조리. 보관에 각별히 주의하여야 함
# 광주시의 식중독 지수 => 주의 : 조리음식은 중심부까지 75℃(어패류 85℃)로 1분 이상 완전히 익히고 외부로 운반할 때에는 가급적 아이스박스 등을 이용하여 10℃이하에서 보관 및 운반
# 대전시의 식중독 지수 => 관심 : 화장실 사용 후, 귀가 후, 조리 전에 손 씻기를 생활화
# 울산시의 식중독 지수 => 위험 : 설사, 구토 등 식중독 의심 증상이 있으면 의료기관을 방문하여 의사 지시에 따름
# 세종시의 식중독 지수 => 경고 : 조리도구는 세척, 소독 등을 거쳐 세균오염을 방지하고 유통기한, 보관방법 등을 확인하여 음식물 조리. 보관에 각별히 주의하여야 함
